# %% [markdown]
# ## Sentiment Analysis - Data Gathering

# %% [markdown]
# We will be using the **Social Network Scraper** library to scrap from couple of website

# %% [markdown]
# if you need to install snscrape use

# %%
#pip install snscrape
#pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# %%
# Importing all the necessary library
#importing needed files
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
# %matplotlib inline

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

import string
import re
import textblob
from textblob import TextBlob

# %%
from wordcloud import WordCloud, STOPWORDS
from emot.emo_unicode import UNICODE_EMOJI
from wordcloud import ImageColorGenerator
from PIL import Image

# %%
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### How to Scrape Tweets from a User with Snscrape

# %%
# Created a list to append all tweet attributes(data)
punch_news = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:MobilePunch').get_items()):
    if i>2000:
        break
    punch_news.append([tweet.id, tweet.date, tweet.likeCount, tweet.replyCount, tweet.sourceLabel, tweet.rawContent,tweet.url,tweet.user.username,tweet.user.location])
    
# Creating a dataframe from the tweets list above 
punch_tweet = pd.DataFrame(punch_news, columns=["id","date_created", "no_of_likes", "no_of_reply", "source", "tweets", "url","username", "location"])


punch_tweet.to_csv('punchnews.csv', mode = 'a')

# %%
punch_tweet.head()
# Out:
#                     id              date_created  no_of_likes  no_of_reply  \
# 0  1561737743931146240 2022-08-22 15:31:08+00:00            2            0
# 1  1561737740395454465 2022-08-22 15:31:07+00:00            6            1
# 2  1561737735412621313 2022-08-22 15:31:06+00:00           24            1
# 3  1561736129560428545 2022-08-22 15:24:43+00:00           15            1
# 4  1561734896120463366 2022-08-22 15:19:49+00:00           84            1
#
#                source                                             tweets  \
# 0  Twitter for iPhone  Credit: Instagram| funkejenifaakindele\n\n--\n...
# 1  Twitter for iPhone  In a TikTok video that she posted on her Insta...
# 2  Twitter for iPhone  Funke Akindele Excited About 45th Birthday\n \...
# 3             Echobox  APC chieftain seeks appointment of more judges...
# 4             Echobox  Vote out bad leaders, LP chieftain urges youth...
#
#                                                  url     username  \
# 0  https://twitter.com/MobilePunch/status/1561737...  MobilePunch
# 1  https://twitter.com/MobilePunch/status/1561737...  MobilePunch
# 2  https://twitter.com/MobilePunch/status/1561737...  MobilePunch
# 3  https://twitter.com/MobilePunch/status/1561736...  MobilePunch
# 4  https://twitter.com/MobilePunch/status/1561734...  MobilePunch
#
#          location
# 0  Lagos, Nigeria
# 1  Lagos, Nigeria
# 2  Lagos, Nigeria
# 3  Lagos, Nigeria
# 4  Lagos, Nigeria

# %%
# read the csv file
punch = pd.read_csv('punchnews.csv', encoding = 'unicode_escape')

# %%
punch.head()
# Out:
#    Unnamed: 0                   id               date_created  no_of_likes  \
# 0           0  1561737743931146240  2022-08-22 15:31:08+00:00            2
# 1           1  1561737740395454465  2022-08-22 15:31:07+00:00            6
# 2           2  1561737735412621313  2022-08-22 15:31:06+00:00           24
# 3           3  1561736129560428545  2022-08-22 15:24:43+00:00           15
# 4           4  1561734896120463366  2022-08-22 15:19:49+00:00           84
#
#    no_of_reply              source  \
# 0            0  Twitter for iPhone
# 1            1  Twitter for iPhone
# 2            1  Twitter for iPhone
# 3            1             Echobox
# 4            1             Echobox
#
#                                               tweets  \
# 0  Credit: Instagram| funkejenifaakindele\n\n--\n...
# 1  In a TikTok video that she posted on her Insta...
# 2  Funke Akindele Excited About 45th Birthday\n \...
# 3  APC chieftain seeks appointment of more judges...
# 4  Vote out bad leaders, LP chieftain urges youth...
#
#                                                  url     username  \
# 0  https://twitter.com/MobilePunch/status/1561737...  MobilePunch
# 1  https://twitter.com/MobilePunch/status/1561737...  MobilePunch
# 2  https://twitter.com/MobilePunch/status/1561737...  MobilePunch
# 3  https://twitter.com/MobilePunch/status/1561736...  MobilePunch
# 4  https://twitter.com/MobilePunch/status/1561734...  MobilePunch
#
#          location
# 0  Lagos, Nigeria
# 1  Lagos, Nigeria
# 2  Lagos, Nigeria
# 3  Lagos, Nigeria
# 4  Lagos, Nigeria

# %% [markdown]
# ### How to Scrape Tweets from a Text Search with Snscrape

# %%
query = 'Peter Obi OR Atiku OR Tinubu OR #Obidient OR #Atikulated OR #Batified OR #BAT2023 OR #OBI2023 OR #Atiku2023 since:2021-01-01 until:2022-08-30'
politics = []
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    if i>20000:
        break
    else:
        politics.append([tweet.id, tweet.date, tweet.likeCount, tweet.replyCount, tweet.sourceLabel, 
                       tweet.rawContent,tweet.url,tweet.user.username,tweet.user.location])

        
        
politics = pd.DataFrame(politics, columns = ["id","date_created", "no_of_likes", 
                                       "no_of_reply", "source", "tweets", "url","username", "location"])

politics.to_csv('politics.csv', mode = 'a')

# %%
politics.head()
# Out:
#                     id              date_created  no_of_likes  no_of_reply  \
# 0  1561791456376938499 2022-08-22 19:04:34+00:00            0            0
# 1  1561791454502076416 2022-08-22 19:04:34+00:00            0            0
# 2  1561791450559422467 2022-08-22 19:04:33+00:00            0            0
# 3  1561791441503936512 2022-08-22 19:04:30+00:00            0            0
# 4  1561791440631504898 2022-08-22 19:04:30+00:00            0            0
#
#                 source                                             tweets  \
# 0  Twitter for Android                       @NigerianAmazon Nwa Ada Igbo
# 1   Twitter for iPhone  @UchePOkoye Peter obi their mate??? Na they ar...
# 2  Twitter for Android  @valerian247 @onlychiko @Egi_nupe_ @Oluwanonso...
# 3  Twitter for Android  @roooooneeeey @DrJoeAbah @PeterObi Tel me the ...
# 4  Twitter for Android  @ayamdapsonfrosh @fortuna_dame Na wa ohh why n...
#
#                                                  url         username  \
# 0  https://twitter.com/Azuanuka_1/status/15617914...       Azuanuka_1
# 1  https://twitter.com/mojo157s/status/1561791454...         mojo157s
# 2  https://twitter.com/Obiageriaku1/status/156179...     Obiageriaku1
# 3  https://twitter.com/Iam_abdulmykeL/status/1561...   Iam_abdulmykeL
# 4  https://twitter.com/ibeanuchiderag1/status/156...  ibeanuchiderag1
#
#                          location
# 0                        Ebenine
# 1
# 2  South Korea with Choi woo shik
# 3                         Nigeria
# 4                  Lagos, Nigeria

# %%
# read the csv file
politic = pd.read_csv('politics.csv')

# %%
politic.head()
# Out:
#    Unnamed: 0                   id               date_created  no_of_likes  \
# 0           0  1561791456376938499  2022-08-22 19:04:34+00:00            0
# 1           1  1561791454502076416  2022-08-22 19:04:34+00:00            0
# 2           2  1561791450559422467  2022-08-22 19:04:33+00:00            0
# 3           3  1561791441503936512  2022-08-22 19:04:30+00:00            0
# 4           4  1561791440631504898  2022-08-22 19:04:30+00:00            0
#
#    no_of_reply               source  \
# 0            0  Twitter for Android
# 1            0   Twitter for iPhone
# 2            0  Twitter for Android
# 3            0  Twitter for Android
# 4            0  Twitter for Android
#
#                                               tweets  \
# 0                       @NigerianAmazon Nwa Ada Igbo
# 1  @UchePOkoye Peter obi their mate??? Na they ar...
# 2  @valerian247 @onlychiko @Egi_nupe_ @Oluwanonso...
# 3  @roooooneeeey @DrJoeAbah @PeterObi Tel me the ...
# 4  @ayamdapsonfrosh @fortuna_dame Na wa ohh why n...
#
#                                                  url         username  \
# 0  https://twitter.com/Azuanuka_1/status/15617914...       Azuanuka_1
# 1  https://twitter.com/mojo157s/status/1561791454...         mojo157s
# 2  https://twitter.com/Obiageriaku1/status/156179...     Obiageriaku1
# 3  https://twitter.com/Iam_abdulmykeL/status/1561...   Iam_abdulmykeL
# 4  https://twitter.com/ibeanuchiderag1/status/156...  ibeanuchiderag1
#
#                          location
# 0                        Ebenine
# 1                             NaN
# 2  South Korea with Choi woo shik
# 3                         Nigeria
# 4                  Lagos, Nigeria
